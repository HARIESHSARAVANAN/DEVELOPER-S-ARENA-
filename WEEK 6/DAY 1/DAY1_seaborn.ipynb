# %% [markdown]
# # ============================================================
# # WEEK 6 - DAY 1: SEABORN BASICS
# # ============================================================
# #
# # PROJECT: Interactive Sales Dashboard
# #
# # OBJECTIVE:
# # Learn the fundamentals of Seaborn and create basic
# # statistical visualizations using the sales dataset.
# #
# # DATASET:
# # sales_data.csv
# #
# # VISUALIZATIONS CREATED:
# # 1. Total Sales by Product
# # 2. Total Sales by Region
# # 3. Daily Sales Trend
# # 4. Distribution of Quantity Sold
# # 5. Number of Transactions by Product
# #
# # LIBRARIES:
# # - Pandas
# # - Matplotlib
# # - Seaborn
# #
# # SKILLS PRACTICED:
# # - Loading CSV data
# # - Data inspection
# # - Date conversion
# # - Data aggregation using groupby()
# # - Creating Seaborn visualizations
# # - Customizing charts
# # - Saving visualizations as PNG files
# #
# # ============================================================

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales_data.csv")

print(df.head())
# Out:
#          Date     Product  Quantity  Price Customer_ID Region  Total_Sales
# 0  2024-01-01       Phone         7  37300     CUST001   East       261100
# 1  2024-01-02  Headphones         4  15406     CUST002  North        61624
# 2  2024-01-03       Phone         2  21746     CUST003   West        43492
# 3  2024-01-04  Headphones         1  30895     CUST004   East        30895
# 4  2024-01-05      Laptop         8  39835     CUST005  North       318680

# %%
print("Shape:", df.shape)

print("\nColumns:")
print(df.columns)

print("\nData Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Shape: (100, 7)
#
# Columns:
# Index(['Date', 'Product', 'Quantity', 'Price', 'Customer_ID', 'Region',
#        'Total_Sales'],
#       dtype='object')
#
# Data Types:
# Date           object
# Product        object
# Quantity        int64
# Price           int64
# Customer_ID    object
# Region         object
# Total_Sales     int64
# dtype: object
#
# Missing Values:
# Date           0
# Product        0
# Quantity       0
# Price          0
# Customer_ID    0
# Region         0
# Total_Sales    0
# dtype: int64

# %%
df["Date"] = pd.to_datetime(df["Date"])

print(df.dtypes)
# Out:
# Date           datetime64[ns]
# Product                object
# Quantity                int64
# Price                   int64
# Customer_ID            object
# Region                 object
# Total_Sales             int64
# dtype: object

# %%
sns.set_theme(style="whitegrid")

# %%
product_sales = (
    df.groupby("Product")["Total_Sales"]
    .sum()
    .sort_values(ascending=False)
)

print(product_sales)
# Out:
# Product
# Laptop        3889210
# Tablet        2884340
# Phone         2859394
# Headphones    1384033
# Monitor       1348071
# Name: Total_Sales, dtype: int64

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    x=product_sales.index,
    y=product_sales.values
)

plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")

plt.tight_layout()
plt.show()

# %%
region_sales = (
    df.groupby("Region")["Total_Sales"]
    .sum()
    .sort_values(ascending=False)
)

print(region_sales)
# Out:
# Region
# North    3983635
# South    3737852
# East     2519639
# West     2123922
# Name: Total_Sales, dtype: int64

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    x=region_sales.index,
    y=region_sales.values
)

plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")

plt.tight_layout()
plt.show()

# %%
daily_sales = (
    df.groupby("Date")["Total_Sales"]
    .sum()
    .reset_index()
)

print(daily_sales.head())
# Out:
#         Date  Total_Sales
# 0 2024-01-01       261100
# 1 2024-01-02        61624
# 2 2024-01-03        43492
# 3 2024-01-04        30895
# 4 2024-01-05       318680

# %%
plt.figure(figsize=(12, 6))

sns.lineplot(
    data=daily_sales,
    x="Date",
    y="Total_Sales",
    marker="o"
)

plt.title("Daily Sales Trend")
plt.xlabel("Date")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.histplot(
    data=df,
    x="Quantity",
    bins=10,
    kde=True
)

plt.title("Distribution of Quantity Sold")
plt.xlabel("Quantity")
plt.ylabel("Number of Transactions")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.countplot(
    data=df,
    x="Product"
)

plt.title("Number of Transactions by Product")
plt.xlabel("Product")
plt.ylabel("Number of Transactions")

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# # ============================================================
# # DAY 1 COMPLETED
# # ============================================================
# #
# # SUMMARY:
# # Successfully loaded and analyzed the sales dataset and
# # created five different visualizations using Seaborn.
# #
# # KEY LEARNING:
# # - Seaborn makes statistical visualization easier.
# # - GroupBy helps summarize sales data by categories.
# # - Line charts are useful for identifying sales trends.
# # - Bar charts help compare products and regions.
# # - Histograms help understand data distributions.
# # - Count plots show the frequency of categorical data.
# #
# # OUTPUT FILES:
# # visualizations/
# # ├── sales_by_product.png
# # ├── sales_by_region.png
# # ├── daily_sales_trend.png
# # ├── quantity_distribution.png
# # └── product_transaction_count.png
# #
# # NEXT:
# # DAY 2 - Statistical Visualization
# # - Box Plots
# # - Violin Plots
# # - Outlier Analysis
# # - Correlation Analysis
# # - Heatmaps
# #
# # ============================================================
